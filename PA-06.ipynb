# %% [markdown]
# > Introdução à Ciência dos Dados \
# > Ciência da Computação – UFV/Florestal
#
#
# * **Nome:** Mateus Henrique Vieira Figueiredo
# * **Matrícula:**  4707
#
# # Aula Prática 06
# ## Visualização de Dados
#
# **Objetivo:** Entender comandos para explorar dados visualmente por meio de gráficos.
# **Pré-requisitos:** Linguagem de programação Python, estatística básica \
# **Meta:** Ao final da prática, o aluno será capaz de analisar um conjunto de dados visualmente para ajudar na tomada de decisões.
#
# ----

# %%
### NÃO REMOVA ESSA CÉLULA! ####
# !pip --no-cache-dir install --upgrade learntools_dados_ufv

# !wget https://raw.githubusercontent.com/gfviegas/CCF425-resources/master/p6/OnlineRetail.xlsx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting learntools_dados_ufv
#   Downloading learntools_dados_ufv-1.0.10.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: learntools_dados_ufv
#   Building wheel for learntools_dados_ufv (setup.py) ... done
#   Created wheel for learntools_dados_ufv: filename=learntools_dados_ufv-1.0.10-py3-none-any.whl size=37100 sha256=356c587c995fcb952db070a52c92069a5ed4e6df6eca3b6fce4463e9fe716c4f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hn1uco1x/wheels/d2/89/23/81594bde6b35d51562684ff88561ce5d961b6228de7fd16b58
# Successfully built learntools_dados_ufv
# Installing collected packages: learntools_dados_ufv
# Successfully installed learntools_dados_ufv-1.0.10
# --2023-05-14 22:46:42--  https://raw.githubusercontent.com/gfviegas/CCF425-resources/master/p6/OnlineRetail.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23715344 (23M) [application/octet-stream]
# Saving to: ‘OnlineRetail.xlsx’
#
# OnlineRetail.xlsx   100%[===================>]  22.62M  77.3MB/s    in 0.3s
#
# 2023-05-14 22:46:43 (77.3 MB/s) - ‘OnlineRetail.xlsx’ saved [23715344/23715344]

# %%
#### Não altere essa célula!!! ####
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Roteiro

# %% [markdown]
# ## Leitura dos dados
# Veja os dados do arquivo `OnlineRetail.xlsx`.
#
# Note que o arquivo é um Excel. A biblioteca consegue ler e o interpretar da mesma maneira que um CSV, como estamos acostumados.
#
# Note que a função usada é a `read_excel` e não a `read_csv`.
#
# É normal que demore um pouco, pois os arquivos em excel possuem muito mais recursos e dados armazenados do que um simples csv.

# %%
df = pd.read_excel('./OnlineRetail.xlsx')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# ### Filtrar quantidades e preços unitários negativos

# %%
df = df[(df['Quantity'] > 0) & (df['UnitPrice'] > 0)]
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [530104 rows x 8 columns]

# %% [markdown]
# ## Visualizar os dados
#
# ### Gráfico de Pontos (_Scatter Plot_)

# %%
df.plot(kind='scatter', x='UnitPrice', y='Quantity', color='orange', label='Transação')
# Adiciona um rótulo no eixo Y
plt.ylabel('Quantidade')
# Adiciona um rótulo no eixo X
plt.xlabel('Preço Unitário')

plt.show()

# %% [markdown]
# ### Usar escala logarítmica nos dois eixos para melhorar a visualização
# Também vamos gerar um gráfico colorindo e marcando por país

# %%
countries_colors = {
    'Brazil': '#FAA916',
    'USA': '#0FA3B1',
    'Canada': '#BB4430'
}

fig, ax = plt.subplots()
countries_data = list(map(lambda k: (k, df[df['Country'] == k]), countries_colors.keys()))
[ax.scatter(x=d['UnitPrice'], y=d['Quantity'], c=countries_colors[k], label=k) for (k, d) in countries_data]

plt.ylabel('Quantidade')
plt.xlabel('Preço Unitário')
plt.xscale('log')
plt.yscale('log')
ax.legend() # Habilita a legenda das cores
plt.show()

# %% [markdown]
# ### Usar um terceiro atributo para definir o tamanho do marcador
#
# Veja o argumento `s` (de size) da função scatter

# %%
df['TotalPrice'] = df['Quantity'] * df['UnitPrice']

fig, ax = plt.subplots()
countries_data = list(map(lambda k: (k, df[df['Country'] == k]), countries_colors.keys()))
[ax.scatter(x=d['UnitPrice'], y=d['Quantity'], c=countries_colors[k], s=d['TotalPrice'], label=k) for (k, d) in countries_data]

plt.ylabel('Quantidade')
plt.xlabel('Preço Unitário')
plt.xscale('log')
plt.yscale('log')
ax.legend() # Habilita a legenda das cores
plt.show()
# Out:
# <ipython-input-14-cf32b30b1a23>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalPrice'] = df['Quantity'] * df['UnitPrice']

# %% [markdown]
# ### Agrupar antes de exibir os gráficos
# Agrupando pelo `InvoiceNo`

# %%
group_invoice = df.groupby('InvoiceNo')

group_invoice.sum().plot.scatter(x='Quantity', y='TotalPrice', c='#EF2D56')
plt.xlabel('Quantidade')
plt.ylabel('Preço Total')
plt.show()
# Out:
# <ipython-input-15-f3633d45bd45>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum().plot.scatter(x='Quantity', y='TotalPrice', c='#EF2D56')

# %% [markdown]
# ### Gerar o mesmo gráfico anterior na escala logarítmica

# %%
group_invoice = df.groupby('InvoiceNo')

group_invoice.sum().plot.scatter(x='Quantity', y='TotalPrice', c='#EF2D56')
plt.xlabel('Quantidade')
plt.ylabel('Preço Total')
plt.xscale('log')
plt.yscale('log')
plt.show()
# Out:
# <ipython-input-16-7aabca3b295a>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum().plot.scatter(x='Quantity', y='TotalPrice', c='#EF2D56')

# %% [markdown]
# ### Plotar gráfico de linha para avaliar tendência.
# Agrupar as compras por data e mostrar a quantidade de itens por data da compra.

# %%
group_date = df.groupby('InvoiceDate')
group_date.sum()['Quantity'].plot(c='#EF2D56')
plt.xlabel('Data Compra')
plt.ylabel('Quantidade')
plt.show()
# Out:
# <ipython-input-17-bad57c7f8abe>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_date.sum()['Quantity'].plot(c='#EF2D56')

# %% [markdown]
# ### Agrupar por Mês/Ano

# %%
df['MonthYear'] = df['InvoiceDate'].dt.strftime('%m/%Y')

group_month_year = df.groupby('MonthYear')
group_month_year.sum()['Quantity'].plot(c='#EF2D56')
plt.xlabel('Data Compra')
plt.ylabel('Quantidade')
plt.show()
# Out:
# <ipython-input-18-8c63bec423d7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MonthYear'] = df['InvoiceDate'].dt.strftime('%m/%Y')
# <ipython-input-18-8c63bec423d7>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_month_year.sum()['Quantity'].plot(c='#EF2D56')

# %% [markdown]
# ### Plotar gráfico de barras para mostrar valores para atributos categóricos

# %%
group_invoice.sum().iloc[0:9]['Quantity'].plot(kind='bar', color='#EF2D56')
plt.xlabel('Número da NF')
plt.ylabel('Quantidade')
plt.show()
# Out:
# <ipython-input-19-1911c4500e22>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum().iloc[0:9]['Quantity'].plot(kind='bar', color='#EF2D56')

# %% [markdown]
# ### Plotar Histograma

# %%
group_invoice.sum()['TotalPrice'].plot(kind='hist', color='#EF2D56')
plt.xlabel('Preço Total')
plt.ylabel('Quantidade')
plt.show()
# Out:
# <ipython-input-20-b381511109ff>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum()['TotalPrice'].plot(kind='hist', color='#EF2D56')

# %% [markdown]
# ### Filtrar para visualizar melhor a maioria
# O gráfico acima possui uma concentração em valores menores mas possui alguns outliers com preço **muito** superior à maioria. Vamos resolver isso com um filtro.

# %%
group_invoice.sum().loc[group_invoice.sum()['TotalPrice'] < 1000]['TotalPrice'].plot(kind='hist', color='#EF2D56')
plt.xlabel('Preço Total')
plt.ylabel('Quantidade')
plt.show()
# Out:
# <ipython-input-21-3249a7471aec>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum().loc[group_invoice.sum()['TotalPrice'] < 1000]['TotalPrice'].plot(kind='hist', color='#EF2D56')
# <ipython-input-21-3249a7471aec>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum().loc[group_invoice.sum()['TotalPrice'] < 1000]['TotalPrice'].plot(kind='hist', color='#EF2D56')

# %% [markdown]
# ### Alterar número de bins para ter mais detalhes

# %%
group_invoice.sum().loc[group_invoice.sum()['TotalPrice'] < 1000]['TotalPrice'].plot(kind='hist', color='#EF2D56', bins=100)
plt.xlabel('Preço Total')
plt.ylabel('Quantidade')
plt.show()
# Out:
# <ipython-input-22-a464e8af570c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum().loc[group_invoice.sum()['TotalPrice'] < 1000]['TotalPrice'].plot(kind='hist', color='#EF2D56', bins=100)
# <ipython-input-22-a464e8af570c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum().loc[group_invoice.sum()['TotalPrice'] < 1000]['TotalPrice'].plot(kind='hist', color='#EF2D56', bins=100)

# %% [markdown]
# ### Plotar um BoxPlot

# %%
group_invoice.sum()['TotalPrice'].plot.box(color='#EF2D56')
plt.ylabel('Preço')
plt.show()
# Out:
# <ipython-input-23-dc603a4e5ac3>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum()['TotalPrice'].plot.box(color='#EF2D56')

# %% [markdown]
# ### Usar escala logarítmica para ver melhor

# %%
group_invoice.sum()['TotalPrice'].plot.box(color='#EF2D56')
plt.ylabel('Preço')
plt.yscale('log')
plt.show()
# Out:
# <ipython-input-24-d25ec2495cb5>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum()['TotalPrice'].plot.box(color='#EF2D56')

# %% [markdown]
# ### Filtrar para valores menores

# %%
group_invoice.sum().loc[group_invoice.sum()['TotalPrice'] < 1000]['TotalPrice'].plot.box(color='#EF2D56')
plt.ylabel('Preço Total')
plt.show()
# Out:
# <ipython-input-25-ca2c8393e02a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum().loc[group_invoice.sum()['TotalPrice'] < 1000]['TotalPrice'].plot.box(color='#EF2D56')
# <ipython-input-25-ca2c8393e02a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum().loc[group_invoice.sum()['TotalPrice'] < 1000]['TotalPrice'].plot.box(color='#EF2D56')

# %% [markdown]
# ### Plotar boxplots agrupados por país

# %%
df.boxplot('TotalPrice', by='Country', rot=90, figsize=(15, 5), color='purple')
plt.ylabel('Preço Total')
plt.yscale('log')
plt.show()

# %% [markdown]
# # Exercícios

# %% [markdown]
# Execute e não remova a célula abaixo antes de iniciar os exercícios. Faça todas as atividades manipulando a variável `df`.

# %%
# Atribui o dataframe com o estado "original" em uma variável isolada
original_df = pd.read_excel('./OnlineRetail.xlsx')
df = original_df
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# ## 1. Faça um gráfico de barras mostrando a quantidade total vendida de cada um dos 10 primeiros produtos que aparecem no Dataframe.
# Essa lista não possui correção automática.

# %%
# Resposta da 1.
df['Quantity'].head(10).plot.bar(xlabel="Index", ylabel="Quantity")
# Out:
# <Axes: xlabel='Index', ylabel='Quantity'>

# %% [markdown]
# ## 2. Faça um Boxplot dos preços unitários dos produtos. Considere somente os 10 produtos mais vendidos.
# Essa lista não possui correção automática.

# %%
from pandas.core import describe
df.sort_values('Quantity', ascending=False).head(10).boxplot('UnitPrice', rot=90, figsize=(15, 5), color='purple')
plt.ylabel('Unit Price')
plt.show()

# %% [markdown]
# ## 3. Faça um gráfico de linhas mostrando o faturamento (total de preços das vendas) por dia.
# Essa lista não possui correção automática.

# %%
# Convert InvoiceDate to datetime
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# Create a new column with the total price (Quantity * UnitPrice)
df['TotalPrice'] = df['Quantity'] * df['UnitPrice']

# Group by date and sum the TotalPrice column
daily_revenue = df.groupby(df['InvoiceDate'].dt.date)['TotalPrice'].sum()

# Create line plot
plt.plot(daily_revenue.index, daily_revenue.values)

# Set x-axis label and title
plt.xlabel('Date')
plt.title('Total Revenue per Day')

# Show plot
plt.show()

# %% [markdown]
# ## 4. Faça o histograma da média dos preços unitários dos produtos.
# Essa lista não possui correção automática.

# %%
# Group by StockCode and calculate mean of UnitPrice
mean_prices = df.groupby('StockCode')['UnitPrice'].mean()

# Create histogram with 20 bins
plt.hist(mean_prices, bins=20)

# Set x-axis label and title
plt.xlabel('Mean Unit Price')
plt.title('Histogram of Mean Unit Prices')

# Show plot
plt.show()

# %% [markdown]
# ## 5. Faça dois gráficos de barras, sendo um da quantidade de compras e outro do total de faturamento por país.
# Essa lista não possui correção automática.

# %%
# Create a new column with the total price (Quantity * UnitPrice)
df['TotalPrice'] = df['Quantity'] * df['UnitPrice']

# Group by country and calculate the sum of Quantity and TotalPrice columns
country_group_sum = df.groupby('Country').agg({'Quantity': 'sum', 'TotalPrice': 'sum'}).reset_index()

# Create bar chart of quantity by country
plt.figure(figsize=(10,6))
sns.barplot(data=country_group_sum, x='Country', y='Quantity')
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Quantity')
plt.title('Quantity of Purchases by Country')
plt.yscale('log')
plt.show()

# Create bar chart of revenue by country
plt.figure(figsize=(10,6))
sns.barplot(data=country_group_sum, x='Country', y='TotalPrice')
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Total Price')
plt.yscale('log')
plt.title('Total Revenue by Country')
plt.show()

# %% [markdown]
# ## 6. Considerando os 100 produtos mais vendidos, é possível visualizar alguma diferença entre a distribuição dos preços unitários desses produtos ao se comparar os países “Australia” e “United Kingdom”? Faça um ou mais gráficos para ajudar a responder.
# Essa lista não possui correção automática.

# %%
# Resposta da 6.

grouped = df.groupby(['Country', 'Description'])['Quantity'].sum().reset_index()

# sort the data in descending order by quantity and select the top product for each country
top_products = grouped.sort_values(['Country', 'Quantity'], ascending=[True, False]).groupby('Country').head(100)

# create a bar plot of the top products and their quantity sold
fig, ax = plt.subplots(figsize=(10, 8))
ax.barh(top_products['Country'], top_products['Quantity'].apply(lambda x: np.log10(x)))
ax.set_xlabel('Country')
ax.set_ylabel('Log Quantity Sold')
ax.set_title('Most Sold Products in Each Country')
plt.show();

# %% [markdown]
# ## 7. Faça um gráfico de barras, de linhas, histograma e boxplot usando a biblioteca `seaborn`.
# Essa lista não possui correção automática.
#
# A biblioteca já está importada pelo nome de `sns`. Vai um gráfico de exemplo abaixo ;)

# %%
country_group_sum = df.groupby('Country').sum().reset_index()
plt.figure(figsize=(10,10))

g=sns.barplot(data=country_group_sum, y='Country', x='Quantity', orient='h')
g.set_xscale('log')

plt.show()

# %%
# Faça outro gráfico de barras com o Seaborn aqui
customer_group_sum = df.groupby('Country').sum().reset_index()
plt.figure(figsize=(10,10))

g=sns.barplot(data=customer_group_sum, y='Country', x='TotalPrice', orient='h')
g.set_xscale('log')

plt.show();
# Out:
# <ipython-input-52-54155fba1ead>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   customer_group_sum = df.groupby('Country').sum().reset_index()

# %%
# Faça outro gráfico de linhas com o Seaborn aqui
country_group_sum = df.groupby('Country').sum().reset_index()
plt.figure(figsize=(10,10))

g=sns.lineplot(data=country_group_sum, y='Country', x='TotalPrice')
g.set_xscale('log')

plt.show()
# Out:
# <ipython-input-54-36d03e6b12c2>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   country_group_sum = df.groupby('Country').sum().reset_index()

# %%
# Faça outro gráfico de histograma com o Seaborn aqui
country_group_sum = df.groupby('Country').sum().reset_index()
plt.figure(figsize=(10,10))

g=sns.histplot(data=country_group_sum, y='Country', x='Quantity')
g.set_xscale('log')

plt.show();
# Out:
# <ipython-input-40-13ef2e8123b6>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   country_group_sum = df.groupby('Country').sum().reset_index()

# %%
# Faça outro gráfico de boxplot com o Seaborn aqui

g=sns.boxplot(data=df, x='UnitPrice')
g.set_xscale('log')

plt.show();

# %% [markdown]
# ## 7. Faça uma breve análise e comparação dos plots feitos com o `seaborn` e com o `matplotlib`.
# Qual você gostou mais? Viu alguma diferença em performance neles?

# %% [markdown]
# Resposta da 7.: Achei ambos as bibliotecas similares, ambas são capazes de produzir diferentes tipos de plots dada um conjunto de dados. Quando rodando as células pude perceber que matplotlib executa mais rápido do que a seaborn.
